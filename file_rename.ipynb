# %%
import os

def replace_dots_in_filenames_keep_extension(root_dir, replacement_char='_'):
    for dirpath, dirnames, filenames in os.walk(root_dir):
        for filename in filenames:
            base_name, ext = os.path.splitext(filename)
            if '.' in base_name:
                # Replace dots in the base name only, not in the extension
                new_base_name = base_name.replace('.', replacement_char)
                # Reassemble the new filename with its original extension
                new_filename = new_base_name + ext
                old_filepath = os.path.join(dirpath, filename)
                new_filepath = os.path.join(dirpath, new_filename)
                # Rename the file
                os.rename(old_filepath, new_filepath)
                print(f'Renamed: {old_filepath} to {new_filepath}')

# %%
import random
import string

def generate_random_filename(include_dot=True):
    """Generate a random filename with or without dots in the base name."""
    base_name_length = random.randint(5, 15)
    base_name = ''.join(random.choices(string.ascii_letters + string.digits, k=base_name_length))

    if include_dot:
        dot_position = random.randint(1, base_name_length - 1)
        base_name = base_name[:dot_position] + '.' + base_name[dot_position:]

    extensions = ['.txt', '.jpg', '.png', '.pdf', '.docx', '.xlsx']
    ext = random.choice(extensions)

    return base_name + ext

def create_test_files(root_dir, num_files, max_depth, current_depth=0):
    """Create num_files with random names in the specified root_dir, with sub-folders up to max_depth."""
    if not os.path.exists(root_dir):
        os.makedirs(root_dir)

    for _ in range(num_files):
        include_dot = random.choice([True, False])
        filename = generate_random_filename(include_dot)
        filepath = os.path.join(root_dir, filename)

        # Create an empty file
        with open(filepath, 'w') as f:
            pass

        print(f'Created file: {filepath}')

    # Randomly create sub-folders if max_depth is not reached
    if current_depth < max_depth:
        num_subfolders = random.randint(1, 3)  # Random number of sub-folders to create
        for _ in range(num_subfolders):
            subfolder_name = ''.join(random.choices(string.ascii_letters + string.digits, k=8))
            subfolder_path = os.path.join(root_dir, subfolder_name)
            create_test_files(subfolder_path, num_files, max_depth, current_depth + 1)

# %%
test_dir = r"C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files"

# %%
create_test_files(test_dir,num_files=10,max_depth=2)
# Out:
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\q1o.d2nf.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\yQQMc.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\jb.0EjKfTO.xlsx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\Laj.ZCSOAIU.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\kuvIyab.h.pdf
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\LB8ReoAls.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\qWbOv.Bf4u7VLo.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\AH4geo27Gv.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ypccnI.docx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ElQXTWZh1R6M.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\JFjpKrHOB.txt
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\SLotu.pdf
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\iPh.b5TWwaICJ7.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\6w.5w39VfqkaCxr.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\8A.qRYC.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\SD.PQk8UHl.docx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\CskoNij73.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\PRp.jaxmLwAwY.pdf
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\ZtcaD5.T3KFRS.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\SgCWFaF8NL2aw.txt
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\coTcL0lK\yxhxq1.w5XXxi.txt
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\coTcL0lK\Le4uFU.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\coTcL0lK\c0OGsp3cQOhAu.Uy.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\coTcL0lK\p.gKpvwGDJ.docx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\coTcL0lK\cBxi.VYvIc.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\coTcL0lK\pPtawVBtl7xw7JC.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\coTcL0lK\Y5wmT.hT.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\coTcL0lK\kZI61XL9C1w0C.docx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\coTcL0lK\lN6V7ZB2b.wX.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\coTcL0lK\tFxbVwrHZ.xlsx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\5UatA9vS\Dn2plt.xlsx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\5UatA9vS\oxx8YENp5k.umVc.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\5UatA9vS\GW.eJ5U6nYCAhC.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\5UatA9vS\aty.1qL9fSnFoC.txt
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\5UatA9vS\IvVhsoYzE.iV2oK.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\5UatA9vS\1cerbipVp6.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\5UatA9vS\Kde0vH.pdf
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\5UatA9vS\QaV.Rhhs028iX8X.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\5UatA9vS\4TWZbTcn5sNoTf.xlsx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\DbsriaY8\5UatA9vS\XJS5Ebny1BDrsP.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\7teU6IS.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\ohN28fIl669SatP.txt
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\lopyoghG.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\k6FISV.pdf
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\4RvqEYUR.xlsx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\5XwbJp3f.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\8.SEmLzLDg.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\y3pXU7sEZvc.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\Gv86ekBSD.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\yeJzrD.8qml.txt
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\ZDDyu3XB\yXxFbsmFDy.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\ZDDyu3XB\DtY7xd9EZHi.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\ZDDyu3XB\g4nR58PLY.AqpX.pdf
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\ZDDyu3XB\3.ffUVG.docx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\ZDDyu3XB\BLYvA96a.pdf
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\ZDDyu3XB\XSl.znQCJ8.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\ZDDyu3XB\EpBDlbfPQVY.pdf
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\ZDDyu3XB\GJ.9pFB2u.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\ZDDyu3XB\74g1.OD5TZ.docx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\ZDDyu3XB\2CDfCAwK.pdf
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\2e2mvvdM\m.rEGWRc2Q.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\2e2mvvdM\PsjW0rJfTwjuql.xlsx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\2e2mvvdM\6bSC.hOA.txt
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\2e2mvvdM\45vUqP8frTZLrwT.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\2e2mvvdM\HIywLfr12kJN.docx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\2e2mvvdM\dOKHWH7jtOfvnl.pdf
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\2e2mvvdM\wVbM7.xlsx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\2e2mvvdM\n7awe.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\2e2mvvdM\bogD9K.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\ecNXChAM\2e2mvvdM\g03AiK.xlsx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\6wRLzNNa.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\Yi.J4Qm22C.docx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\HX5nGVleaYO8.mEd.pdf
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\WQwaMUQ7d.ZwL.pdf
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\9Q8dl.2W5BCS8x.docx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\ot2yDnOPK4oWpTx.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\52oadSZ86OaTjVv.docx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\Alfv9gj.N3DS9.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\F5zvx0tJZysqrw.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\0gMAYAZjXhNPQ.txt
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\1gXAAWvz\WgRhadM.tlfs6p4h.docx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\1gXAAWvz\LvmD4dIB.xlsx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\1gXAAWvz\2B7zupNwF.txt
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\1gXAAWvz\T48TULw4Vp6qC7.docx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\1gXAAWvz\Yibk2j7.xlsx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\1gXAAWvz\cxStkBFb.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\1gXAAWvz\c9b.7Zx.xlsx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\1gXAAWvz\A4bU0.eRWzPYZ4.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\1gXAAWvz\J.7a1R5.pdf
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\1gXAAWvz\aqpaZA9d3BJjy5q.txt
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\l9wYsKjU\P1elZ.pdf
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\l9wYsKjU\5yZ1n.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\l9wYsKjU\jkgXu6P2Bc1.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\l9wYsKjU\mNYy9.rFb6SG.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\l9wYsKjU\jJRDfgVK.Pp.txt
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\l9wYsKjU\5mGy7ylsmrJxytg.docx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\l9wYsKjU\A4HzpZ.docx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\l9wYsKjU\BZEGG52.docx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\l9wYsKjU\vKv6cvD.txt
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\l9wYsKjU\lcI.UCPSBZ.jpg
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\HdHHjjZq\5yN.ylnamv.txt
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\HdHHjjZq\B1.S1vIw.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\HdHHjjZq\fbKLtpJ.n88.txt
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\HdHHjjZq\t.rKkhLn.txt
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\HdHHjjZq\s6cSQntd3aPE6z.txt
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\HdHHjjZq\YOHS.cb.png
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\HdHHjjZq\czb4idUEkf4zFjW.pdf
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\HdHHjjZq\44y.wc.docx
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\HdHHjjZq\rN6ge5.pdf
# Created file: C:\Users\StewarCa\projects-2024\useful-mercury-api-cases\file-rename\test_files\sZGH16pv\HdHHjjZq\REQjdT.txt

# %%
# Can run this function within the notebook.
replace_dots_in_filenames_keep_extension(test_dir)
